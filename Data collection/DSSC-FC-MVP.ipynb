# %% [markdown]
# # DSSC-FC-MVP.ipynb is for developing
# # an algorith for Stock Prediction

# %%
# !pip install yfinance

# %%
# !pip install yahoofinancials

# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %% [markdown]
# ### Code to fetch Stock historical data of IBM

# %%
IBM_df = yf.download('IBM', start = '2021-01-01', 
                     end = '2021-12-31', progress = 'False')
IBM_df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  120.315491  120.382408  117.629066  118.489487  112.813454
# 2021-01-05  119.512428  121.108986  119.130020  120.592735  114.815948
# 2021-01-06  121.319313  126.080307  121.147224  123.604210  117.683167
# 2021-01-07  124.321220  124.722755  122.619499  123.317398  117.410103
# 2021-01-08  122.915871  123.632889  121.395790  122.877632  116.991402
#
#              Volume
# Date
# 2021-01-04  5417443
# 2021-01-05  6395872
# 2021-01-06  8322708
# 2021-01-07  4714740
# 2021-01-08  4891305

# %%
IBM_open = IBM_df['Open'].plot()
IBM_close = IBM_df['Adj Close'].plot()
plt.show()

# %%
IBM_df.to_csv('IBM.csv', index = 'False', 
              header = 'True')
IBM_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  120.315491  120.382408  117.629066  118.489487  112.813454
# 2021-01-05  119.512428  121.108986  119.130020  120.592735  114.815948
# 2021-01-06  121.319313  126.080307  121.147224  123.604210  117.683167
# 2021-01-07  124.321220  124.722755  122.619499  123.317398  117.410103
# 2021-01-08  122.915871  123.632889  121.395790  122.877632  116.991402
# ...                ...         ...         ...         ...         ...
# 2021-12-23  130.000000  130.960007  129.520004  130.630005  130.630005
# 2021-12-27  130.630005  131.649994  129.949997  131.619995  131.619995
# 2021-12-28  131.600006  133.220001  131.589996  132.630005  132.630005
# 2021-12-29  132.399994  134.210007  132.300003  133.350006  133.350006
# 2021-12-30  133.750000  134.369995  133.330002  133.910004  133.910004
#
#              Volume
# Date
# 2021-01-04  5417443
# 2021-01-05  6395872
# 2021-01-06  8322708
# ...

# %% [markdown]
# ### Code to fetch Stock data of Microsoft

# %%
MS_df = yf.download('MS', start = '2021-01-01', 
                    end = '2021-12-31', progress = 'False')
MS_df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2021-01-04  69.279999  69.930000  67.720001  68.330002  66.276009  14014600
# 2021-01-05  68.160004  70.080002  68.080002  69.489998  67.401138  11120400
# 2021-01-06  71.410004  74.879997  70.559998  73.680000  71.465187  18334300
# 2021-01-07  74.800003  76.510002  74.800003  74.940002  72.687309  13530400
# 2021-01-08  74.470001  75.339996  73.849998  75.250000  72.987991  12896700

# %%
MS_open = MS_df['Open'].plot()
MS_close = MS_df['Adj Close'].plot()
plt.show()

# %%
MS_df.to_csv('MS.csv', index = 'False', 
             header = 'True')
MS_df
# Out:
#                   Open        High        Low       Close  Adj Close    Volume
# Date
# 2021-01-04   69.279999   69.930000  67.720001   68.330002  66.276009  14014600
# 2021-01-05   68.160004   70.080002  68.080002   69.489998  67.401138  11120400
# 2021-01-06   71.410004   74.879997  70.559998   73.680000  71.465187  18334300
# 2021-01-07   74.800003   76.510002  74.800003   74.940002  72.687309  13530400
# 2021-01-08   74.470001   75.339996  73.849998   75.250000  72.987991  12896700
# ...                ...         ...        ...         ...        ...       ...
# 2021-12-23   99.010002   99.970001  98.769997   99.339996  98.652527   4482200
# 2021-12-27   99.720001  100.529999  99.110001  100.400002  99.705193   4196000
# 2021-12-28  100.599998  101.000000  99.580002   99.970001  99.278168   4269700
# 2021-12-29  100.050003  100.510002  98.690002   98.730003  98.046753   6923100
# 2021-12-30   98.860001   99.970001  98.720001   98.800003  98.116264   3564900
#
# ...

# %% [markdown]
# ## Visualization of Historic Stock Data

# %%
import seaborn
import matplotlib.pyplot as plt
